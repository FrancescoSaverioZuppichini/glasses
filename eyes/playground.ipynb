# %%
from nn.blocks.residuals import ResidualAdd
import torch.nn as nn
from collections import OrderedDict
import torch
from torch import Tensor
from torchsummary import summary

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
from nn.resnet import *

# %%
x = torch.rand(1, 32,112,112)
block = ResNetBottleNeckBlock(32, 64)
print(block)
block(x).shape
# Out:
# ResNetBottleNeckBlock(
#   (block): Residual(
#     (block): Sequential(
#       (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (shortcut): ResNetShorcut(
#       (conv): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (act): ReLU()
# )
# torch.Size([1, 256, 112, 112])

# %%
from nn.resnet import resnet101
model = resnet101(3, 1000)
# summary(model.cuda(), (3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5          [-1, 256, 56, 56]          16,384
#        BatchNorm2d-6          [-1, 256, 56, 56]             512
#      ResNetShorcut-7          [-1, 256, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-12           [-1, 64, 56, 56]             128
#              ReLU-13           [-1, 64, 56, 56]               0
# ...

# %%
x = torch.rand(1, 3,224,224)

# %%
# %timeit

from nn.resnet import resnet101
model = resnet101(3, 1000)
model(x)
# Out:
# tensor([[ 2.8869e-01,  4.0442e-01,  8.4309e-01,  1.0264e+00,  3.8376e-01,
#          -1.3265e+00,  5.0664e-01,  1.5127e+00,  9.1721e-01,  1.5627e-01,
#           3.4596e-01, -2.4833e-01, -5.2827e-01, -1.1457e-01, -2.4209e-02,
#           1.7605e-01, -7.3397e-01,  3.2526e-01, -3.0598e-01,  5.7972e-01,
#           5.8165e-01,  4.8870e-01,  1.0273e+00, -6.9778e-01, -4.2378e-01,
#          -4.7580e-01,  1.8119e-01, -2.7024e-01,  4.5312e-01,  1.0692e+00,
#           6.5276e-01,  5.5119e-01,  1.3744e+00,  6.2132e-01, -6.0310e-01,
#          -6.2841e-01,  6.1213e-02, -3.8454e-01, -5.4196e-01,  1.0555e-01,
#          -8.0648e-01, -2.1817e-01, -3.6783e-01, -2.4121e-01, -2.5588e-02,
#           2.9102e-01,  2.8916e-01, -2.2917e-02,  5.3450e-01,  2.9007e-01,
#           1.5014e-01, -8.6310e-01, -6.5583e-01, -3.3942e-01, -8.8152e-01,
#           4.8576e-02, -5.3216e-01,  8.9345e-01, -3.6323e-01,  3.4919e-01,
#          -6.7870e-01,  1.6526e-01,  5.0427e-01, -8.1421e-01, -2.2985e-01,
# ...

# %%
from torchvision.models import resnet101

# %%
# %timeit
resnet101(False)(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-122-034ae6f4013e> in <module>
#       1 get_ipython().run_line_magic('timeit', '')
# ----> 2 resnet101(False)(x)
#
# ~/anaconda3/envs/dl/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/dl/lib/python3.8/site-packages/torchvision/models/resnet.py in forward(self, x)
#     218
#     219     def forward(self, x):
# --> 220         return self._forward_impl(x)
#     221
#     222
#
# ~/anaconda3/envs/dl/lib/python3.8/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
# ...
