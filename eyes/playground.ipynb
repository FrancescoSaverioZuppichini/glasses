# %%
from nn.blocks.residuals import ResidualAdd
import torch.nn as nn
from collections import OrderedDict
import torch
from torch import Tensor
from torchsummary import summary

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x = torch.rand(1, 3,224,224)

# %%
# %%timeit
from torchvision.models import resnet101

_ = resnet101(False)(x)
# Out:
# 660 ms ± 35 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
from nn.resnet import resnet101
model = resnet101(3, 1000)
_ = model(x)
# Out:
# 797 ms ± 30.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
??BasicBlock

# %%
from torchvision.models.resnet import Bottleneck

??Bottleneck

# %%
Bottleneck(32, 64)
# Out:
# Bottleneck(
#   (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )

# %%
from torchvision.models import resnet50

resnet50(False)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
from nn.resnet import resnet50
resnet50(3, 1000)
# Out:
# ResNet(
#   (encoder): ResNetEncoder(
#     (gate): Sequential(
#       (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (blocks): ModuleList(
#       (0): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBottleNeckBlock(
#             (block): Sequential(
#               (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act1): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# %%timeit
from torchvision.models.resnet import Bottleneck
x = torch.rand(1, 32,224,224)
vision_b = Bottleneck(32, 32)
vision_b(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-46c125869959> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', 'from torchvision.models.resnet import Bottleneck\nx = torch.rand(1, 32,224,224)\nvision_b = Bottleneck(32, 32)\nvision_b(x)\n')
#
# ~/anaconda3/envs/dl/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# <decorator-gen-60> in timeit(self, line, cell, local_ns)
#
# ~/anaconda3/envs/dl/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...

# %%
# %%timeit

from nn.resnet import ResNetBottleNeckBlock
x = torch.rand(1, 32,224,224)
vision_b = ResNetBottleNeckBlock(32, 32)
vision_b(x)
# Out:
# 42.3 ms ± 2.43 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
