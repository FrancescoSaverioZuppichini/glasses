# %%
from nn.blocks.residuals import ResidualAdd
import torch.nn as nn
from collections import OrderedDict
import torch
from torch import Tensor

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
from nn.resnet import *

# %%
x = torch.rand(1, 32,40,40)
block = ResNetBottleNeckBlock(32, 64)
print(block)
block(x).shape
# Out:
# ResNetBottleNeckBlock(
#   (block): Residual(
#     (block): Sequential(
#       (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (shortcut): ResNetShorcut(
#       (conv): Conv2d(32, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (act): ReLU(inplace=True)
# )
# torch.Size([1, 256, 20, 20])

# %%
model = resnet18(3, 1000)

# %%
# model
# Out:
# ResNet(
#   (encoder): ResNetEncoder(
#     (gate): Sequential(
#       (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (blocks): ModuleList(
#       (0): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#           (1): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#         )
#       )
#       (1): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (shortcut): ResNetShorcut(
#                 (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#           (1): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#         )
#       )
#       (2): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (shortcut): ResNetShorcut(
#                 (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#           (1): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#         )
#       )
#       (3): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (shortcut): ResNetShorcut(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#           (1): ResNetBasicBlock(
#             (block): Residual(
#               (block): Sequential(
#                 (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act1): ReLU()
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (decoder): ResnetDecoder(
#     (avg): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
# )

# %%
from torchsummary import summary

# %%
summary(model.cuda(), (3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#          Residual-10           [-1, 64, 56, 56]               0
#              ReLU-11           [-1, 64, 56, 56]               0
#  ResNetBasicBlock-12           [-1, 64, 56, 56]               0
#            Conv2d-13           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-14           [-1, 64, 56, 56]             128
#              ReLU-15           [-1, 64, 56, 56]               0
#            Conv2d-16           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-17           [-1, 64, 56, 56]             128
#          Residual-18           [-1, 64, 56, 56]               0
#              ReLU-19           [-1, 64, 56, 56]               0
#  ResNetBasicBlock-20           [-1, 64, 56, 56]               0
#       ResNetLayer-21           [-1, 64, 56, 56]               0
#            Conv2d-22          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#     ResNetShorcut-24          [-1, 128, 28, 28]               0
#            Conv2d-25          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-26          [-1, 128, 28, 28]             256
#              ReLU-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#          Residual-30          [-1, 128, 28, 28]               0
#              ReLU-31          [-1, 128, 28, 28]               0
#  ResNetBasicBlock-32          [-1, 128, 28, 28]               0
#            Conv2d-33          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-34          [-1, 128, 28, 28]             256
#              ReLU-35          [-1, 128, 28, 28]               0
#            Conv2d-36          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-37          [-1, 128, 28, 28]             256
#          Residual-38          [-1, 128, 28, 28]               0
#              ReLU-39          [-1, 128, 28, 28]               0
#  ResNetBasicBlock-40          [-1, 128, 28, 28]               0
#       ResNetLayer-41          [-1, 128, 28, 28]               0
#            Conv2d-42          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-43          [-1, 256, 14, 14]             512
#     ResNetShorcut-44          [-1, 256, 14, 14]               0
#            Conv2d-45          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-46          [-1, 256, 14, 14]             512
#              ReLU-47          [-1, 256, 14, 14]               0
#            Conv2d-48          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-49          [-1, 256, 14, 14]             512
#          Residual-50          [-1, 256, 14, 14]               0
#              ReLU-51          [-1, 256, 14, 14]               0
#  ResNetBasicBlock-52          [-1, 256, 14, 14]               0
#            Conv2d-53          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-54          [-1, 256, 14, 14]             512
#              ReLU-55          [-1, 256, 14, 14]               0
#            Conv2d-56          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-57          [-1, 256, 14, 14]             512
#          Residual-58          [-1, 256, 14, 14]               0
#              ReLU-59          [-1, 256, 14, 14]               0
#  ResNetBasicBlock-60          [-1, 256, 14, 14]               0
#       ResNetLayer-61          [-1, 256, 14, 14]               0
#            Conv2d-62            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-63            [-1, 512, 7, 7]           1,024
#     ResNetShorcut-64            [-1, 512, 7, 7]               0
#            Conv2d-65            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-66            [-1, 512, 7, 7]           1,024
#              ReLU-67            [-1, 512, 7, 7]               0
#            Conv2d-68            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-69            [-1, 512, 7, 7]           1,024
#          Residual-70            [-1, 512, 7, 7]               0
#              ReLU-71            [-1, 512, 7, 7]               0
#  ResNetBasicBlock-72            [-1, 512, 7, 7]               0
#            Conv2d-73            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-74            [-1, 512, 7, 7]           1,024
#              ReLU-75            [-1, 512, 7, 7]               0
#            Conv2d-76            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-77            [-1, 512, 7, 7]           1,024
#          Residual-78            [-1, 512, 7, 7]               0
#              ReLU-79            [-1, 512, 7, 7]               0
#  ResNetBasicBlock-80            [-1, 512, 7, 7]               0
#       ResNetLayer-81            [-1, 512, 7, 7]               0
#     ResNetEncoder-82            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-83            [-1, 512, 1, 1]               0
#            Linear-84                 [-1, 1000]         513,000
#     ResnetDecoder-85                 [-1, 1000]               0
# ================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 72.94
# Params size (MB): 44.59
# Estimated Total Size (MB): 118.11
# ----------------------------------------------------------------

# %%
layer = ResNetLayer(32, 64, block=ResNetBottleNeckBlock, n=2)
print(layer)
layer(x)
# Out:
# ResNetLayer(
#   (blocks): Sequential(
#     (0): ResNetBottleNeckBlock(
#       (block): Residual(
#         (block): Sequential(
#           (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (shortcut): ResNetShorcut(
#           (conv): Conv2d(32, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (act): ReLU(inplace=True)
#     )
#     (1): ResNetBottleNeckBlock(
#       (block): Residual(
#         (block): Sequential(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (shortcut): ResNetShorcut(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (act): ReLU(inplace=True)
#     )
#   )
# )
# tensor([[[[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 1.1499e+00,
#            0.0000e+00, 1.2663e+00],
#           [1.1296e+00, 0.0000e+00, 0.0000e+00,  ..., 2.7397e+00,
#            3.6240e-01, 3.5898e-01],
#           [0.0000e+00, 1.4933e-01, 1.4434e+00,  ..., 0.0000e+00,
#            2.0713e+00, 4.4525e-01],
#           ...,
#           [0.0000e+00, 1.7361e+00, 0.0000e+00,  ..., 1.5195e+00,
#            7.9135e-01, 0.0000e+00],
#           [0.0000e+00, 3.9639e-01, 5.8206e-01,  ..., 0.0000e+00,
#            0.0000e+00, 1.9019e+00],
#           [6.9278e-01, 0.0000e+00, 2.4074e-01,  ..., 0.0000e+00,
#            4.5095e-01, 0.0000e+00]],
#
#          [[0.0000e+00, 1.2233e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 1.4205e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [9.5205e-01, 2.2595e+00, 0.0000e+00,  ..., 1.8927e-02,
#            0.0000e+00, 9.5085e-01],
#           ...,
#           [2.2544e+00, 1.9612e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.3485e+00, 0.0000e+00, 1.1612e+00,  ..., 0.0000e+00,
#            1.0838e+00, 2.2115e+00],
#           [0.0000e+00, 3.2437e-01, 0.0000e+00,  ..., 1.3218e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[7.8740e-01, 2.1133e+00, 7.3538e-01,  ..., 2.3016e+00,
#            1.0399e-01, 1.1250e+00],
#           [1.3000e+00, 5.7636e-01, 1.3662e+00,  ..., 2.6429e+00,
#            0.0000e+00, 9.9866e-01],
#           [0.0000e+00, 1.2015e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.4778e-01],
#           ...,
#           [0.0000e+00, 9.9908e-01, 0.0000e+00,  ..., 7.6919e-01,
#            3.0039e-01, 0.0000e+00],
#           [5.2638e-01, 4.6590e-01, 0.0000e+00,  ..., 0.0000e+00,
#            5.1058e-01, 0.0000e+00],
#           [0.0000e+00, 9.3444e-01, 1.3608e+00,  ..., 0.0000e+00,
#            4.6721e-01, 0.0000e+00]],
#
#          ...,
#
#          [[1.9469e+00, 7.0230e-01, 7.9875e-01,  ..., 3.4256e-01,
#            5.2348e-01, 0.0000e+00],
#           [4.3795e-01, 4.3957e-01, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.0651e-01],
#           [0.0000e+00, 0.0000e+00, 3.1923e-01,  ..., 3.6489e+00,
#            4.6526e-01, 2.5530e-01],
#           ...,
#           [0.0000e+00, 2.6451e+00, 3.0875e+00,  ..., 2.1180e-01,
#            5.3490e-01, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 1.8663e-02,  ..., 9.1374e-01,
#            0.0000e+00, 3.6367e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 1.4295e+00,
#            0.0000e+00, 7.1579e-01]],
#
#          [[7.9877e-01, 1.2259e+00, 3.3791e-02,  ..., 3.1263e+00,
#            0.0000e+00, 4.1008e-01],
#           [0.0000e+00, 0.0000e+00, 7.3519e-01,  ..., 1.0171e+00,
#            9.0994e-02, 0.0000e+00],
#           [9.3600e-01, 2.3857e+00, 6.5272e-01,  ..., 4.0925e-01,
#            4.0996e-01, 0.0000e+00],
#           ...,
#           [3.0226e-01, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            5.7529e-01, 1.2250e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 1.5377e+00],
#           [5.9449e-01, 0.0000e+00, 1.3320e+00,  ..., 0.0000e+00,
#            6.1381e-01, 6.0920e-01]],
#
#          [[1.4900e-01, 0.0000e+00, 2.2956e-03,  ..., 0.0000e+00,
#            2.9586e-01, 0.0000e+00],
#           [0.0000e+00, 3.0887e+00, 0.0000e+00,  ..., 5.8708e-01,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 2.6144e-01, 0.0000e+00,  ..., 9.5065e-02,
#            7.4447e-01, 1.4486e+00],
#           ...,
#           [0.0000e+00, 0.0000e+00, 8.9337e-01,  ..., 0.0000e+00,
#            6.8779e-02, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 1.6451e+00,  ..., 0.0000e+00,
#            1.7682e-02, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 2.9722e+00,  ..., 8.6661e-02,
#            5.3148e-01, 6.8516e-01]]]], grad_fn=<ReluBackward1>)
